# %%
import pandas as pd
df = pd.read_csv('all_drinks.csv')
df.head()
# Out:
#    Unnamed: 0                              strDrink         dateModified  \
# 0           0  '57 Chevy with a White License Plate  2016-07-18 22:49:04
# 1           1                        1-900-FUK-MEUP  2016-07-18 22:27:04
# 2           2                      110 in the shade  2016-02-03 14:51:57
# 3           3                151 Florida Bushwacker  2016-07-18 22:28:43
# 4           4                           155 Belmont  2016-10-05 12:36:28
#
#    idDrink strAlcoholic           strCategory  \
# 0    14029    Alcoholic              Cocktail
# 1    15395    Alcoholic                  Shot
# 2    15423    Alcoholic                  Beer
# 3    14588    Alcoholic  Milk / Float / Shake
# 4    15346    Alcoholic              Cocktail
#
#                                        strDrinkThumb             strGlass  \
# 0  http://www.thecocktaildb.com/images/media/drin...       Highball glass
# 1  http://www.thecocktaildb.com/images/media/drin...  Old-fashioned glass
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
onehot = OneHotEncoder(categories='auto', dtype=None, handle_unknown='error')
onehot.fit(df['strIngredient1'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [3], in <module>
#       1 from sklearn.preprocessing import OneHotEncoder
#       2 onehot = OneHotEncoder(categories='auto', dtype=None, handle_unknown='error')
# ----> 3 onehot.fit(df['strIngredient1'])
#
# File /usr/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:461, in OneHotEncoder.fit(self, X, y)
#     443 """
#     444 Fit OneHotEncoder to X.
#     445
#    (...)
#     458     Fitted encoder.
#     459 """
#     460 self._validate_keywords()
# --> 461 self._fit(X, handle_unknown=self.handle_unknown, force_all_finite="allow-nan")
#     462 self.drop_idx_ = self._compute_drop_idx()
#     463 return self
#
# File /usr/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:77, in _BaseEncoder._fit(self, X, handle_unknown, force_all_finite)
#      75 self._check_n_features(X, reset=True)
# ...
