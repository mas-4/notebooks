# %%
import pandas as pd
import numpy as np
np.random.seed(42)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os

# %%
# %ls /grande/wikiart
# Out:
# Abstract_Expressionism/  Expressionism/               Pointillism/
# Action_painting/         Fauvism/                     Pop_Art/
# Analytical_Cubism/       High_Renaissance/            Post_Impressionism/
# Art_Nouveau_Modern/      Impressionism/               Realism/
# Baroque/                 Mannerism_Late_Renaissance/  Rococo/
# Color_Field_Painting/    Minimalism/                  Romanticism/
# Contemporary_Realism/    Naive_Art_Primitivism/       Symbolism/
# Cubism/                  New_Realism/                 Synthetic_Cubism/
# Early_Renaissance/       Northern_Renaissance/        Ukiyo_e/

# %%
# %ls /grande/wikiart/Abstract_Expressionism/
# Out:
#  aaron-siskind_acolman-1-1955.jpg
#  aaron-siskind_chicago-1951.jpg
#  aaron-siskind_chicago-6-1961.jpg
#  aaron-siskind_feet-102-1957.jpg
#  aaron-siskind_gloucester-16a-1944.jpg
#  aaron-siskind_jerome-arizona-1949.jpg
#  aaron-siskind_kentucky-4-1951.jpg
#  aaron-siskind_new-york-1951.jpg
#  aaron-siskind_new-york-2-1948.jpg
#  aaron-siskind_new-york-24-1988.jpg
#  aaron-siskind_new-york-40-1986.jpg
#  aaron-siskind_new-york-city-w-1-1947.jpg
#  aaron-siskind_per-400-1983.jpg
#  aaron-siskind_pleasures-and-terrors-of-levitation-25-1957.jpg
#  aaron-siskind_providence-92-1986.jpg
#  aaron-siskind_recife-olinda-8-1968.jpg
#  aaron-siskind_rome-arch-of-constantine-10-1963.jpg
#  aaron-siskind_the-tree-35-1973.jpg
#  aaron-siskind_uruapan-11-1955.jpg
#  aaron-siskind_utah-84-1976.jpg
#  aaron-siskind_vera-cruz-96-1973.jpg
#  aaron-siskind_westport-10-1988.jpg
#  aaron-siskind_yuchitan-1-1955.jpg
#  abidin-dino_abstract-composition.jpg
#  abidin-dino_antibes-1961-1.jpg
# ...

# %%
for directory in os.walk('')
